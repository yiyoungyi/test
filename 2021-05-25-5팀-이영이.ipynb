# %%
test1 = 1
print(test1)
print(type(test1))   # 데이터 형
print(id(test1))     # 데이터 주소
# Out:
# 1
# <class 'int'>
# 94611935181312

# %% [markdown]
# # New Section

# %%
test1 = 1.0
print(test1)
print(type(test1))   # 데이터 형
print(id(test1))     # 데이터 주소
# Out:
# 1.0
# <class 'float'>
# 140469924238192

# %%
test1 = "안녕"
print(test1)
print(type(test1))   # 데이터 형
print(id(test1))     # 데이터 주소
# Out:
# 안녕
# <class 'str'>
# 140469862966544

# %%
test1 = True
print(test1)
print(type(test1))   # 데이터 형
print(id(test1))     # 데이터 주소
# Out:
# True
# <class 'bool'>
# 94611934507264

# %%
test1 = [1,2,3]
print(test1)
print(type(test1))   # 데이터 형
print(id(test1))     # 데이터 주소
# Out:
# [1, 2, 3]
# <class 'list'>
# 140469796315856

# %%
test1 = (1,2,3)
print(test1)
print(type(test1))   # 데이터 형
print(id(test1))     # 데이터 주소
# Out:
# (1, 2, 3)
# <class 'tuple'>
# 140469796103744

# %%
test1 = {"이름": "이영이", "나이": 39}
print(test1)
print(type(test1))   # 데이터 형
print(id(test1))     # 데이터 주소
# Out:
# {'이름': '이영이', '나이': 39}
# <class 'dict'>
# 140469795483968

# %%
test1 = {1981,"이영이",39, "여성"}
print(test1)
print(type(test1))   # 데이터 형
print(id(test1))     # 데이터 주소
# Out:
# {'이영이', 1981, '여성', 39}
# <class 'set'>
# 140469795074848

# %%
test1 = {12,29,"생일","거주지","서울", 8}
print(test1)
print(type(test1))   # 데이터 형
print(id(test1))     # 데이터 주소
# Out:
# {'거주지', '서울', 8, 12, '생일', 29}
# <class 'set'>
# 140469795075808

# %%
test1 = {"순서","테스트","숫자", 0,1,2}
print(test1)
print(type(test1))   # 데이터 형
print(id(test1))     # 데이터 주소
# Out:
# {0, 1, 2, '숫자', '순서', '테스트'}
# <class 'set'>
# 140469796153776

# %%
test1 = {"이름",'이름','이름2',"이름2",1,2,2,3}
print(test1)
print(type(test1))   # 데이터 형
print(id(test1))     # 데이터 주소
# Out:
# {1, 2, 3, '이름2', '이름'}
# <class 'set'>
# 140469795076768

# %%
a = input('화씨온도:')
a = int(a)
print('섭씨온도:',(a-32)* 5/9)
# Out:
# 화씨온도:99
# 섭씨온도: 37.22222222222222

# %%
a = input('밑변:')
b = input('높이:')
print(a+b)

a = int(a)
b = int(b)
print('삼각형의 넓이:', a*b/2)
# Out:
# 밑변:4
# 높이:3
# 43
# 삼각형의 넓이: 6.0

# %%
x = 10
x += 20
print(x)
# Out:
# 30

# %%
x = 3
y = 5
x *= x + y
# x = x * (x + y) 위의 수식과 같음
print(x)
# Out:
# 24

# %%
# error 문자열 연결시 숫자 포함
english = 100
result = '영어점수' + english + '점'
print(result)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-f80f50d2aadc> in <module>()
#       1 # error 문자열 연결시 숫자 포함
#       2 english = 100
# ----> 3 result = '영어점수' + english + '점'
#       4 print(result)
#
# TypeError: can only concatenate str (not "int") to str

# %%
# 문자열 연결시 숫자 포함
english = 100
result = '영어점수' + str(english) + '점'
print(result)
# Out:
# 영어점수100점

# %%
오늘 {경기장}에서 경기가 열렸습니다.
{이긴팀}와(과) {진팀}은 치열한 공방전을 펼쳤습니다.
{vip}이(가) 맹활약을 펼쳤습니다.
결국 {이긴팀}이(가) {진팀}을(를) {스코어}로 이겼습니다.

# %%
sta=input('경기장: ')
winner=input('이긴팀: ')
loser=input('진팀: ')
vip=input('vip: ')
score=input('스코어: ')\

print(f'''오늘 {sta}에서 경기가 열렸습니다.
{winner}와(과) {loser}은(는) 치열한 공방전을 펼쳤습니다.
{vip}이(가) 맹활약을 펼쳤습니다.
결국 {winner}이(가) {loser}을(를) {score}로 이겼습니다.''')
# Out:
# 경기장: 서울
# 이긴팀: LG
# 진팀: 두산
# vip: 만수
# 스코어: 100
# 오늘 서울에서 경기가 열렸습니다.
# LG와(과) 두산은(는) 치열한 공방전을 펼쳤습니다.
# 만수이(가) 맹활약을 펼쳤습니다.
# 결국 LG이(가) 두산을(를) 100로 이겼습니다.

# %%
{지역}에 위치한 아주 좋은 {매물종류}이(가) 매물로 나왔습니다.
이 {메물종류}는 {평}평으로 {방개수}개의 방을 가지고 있습니다.
가격은 {가격}만원 입니다.

# %%
지역 = input(str()
매물종류 = input(str())
평수 = input(int())
방개수 = input(int())
가격 = input(int())\

print(f'''{지역}에 위치한 아주 좋은 {매물종류}이(가) 매물로 나왔습니다.
이 {매물종류}는 {평수}평으로 {방개수}개의 방을 가지고 있습니다.
가격은 {가격}만원 입니다.''')
# Out:
# 서울
# 아파트
# 30
# 3
# 100000
# 서울에 위치한 아주 좋은 아파트이(가) 매물로 나왔습니다.
# 이 아파트는 30평으로 3개의 방을 가지고 있습니다.
# 가격은 100000만원 입니다.

# %%
name = str(input('이름을 입력하세요: '))
korean = int(input('국어성적을 입력하세요: '))
english = int(input('영어성적을 입력하세요: '))
math = int(input('수학성적을 입력하세요: '))
sum = (korean + english + math)/3

print(f'''평균성적은 {sum}점 입니다.''')
# Out:
# 이름을 입력하세요: 이영이
# 국어성적을 입력하세요: 30
# 영어성적을 입력하세요: 40
# 수학성적을 입력하세요: 100
# 평균성적은 56.666666666666664점 입니다.

# %%
ame = int(input('아메리카노 판매 갯수: '))
latte = int(input('카페라떼 판매 갯수: '))
chino = int(input('카푸치노 판매 갯수: '))
price = (ame*2000) + (latte*3000) + (chino*3500)

print('총 매출은 ', price, '원입니다.')
# Out:
# 아메리카노 판매 갯수: 3
# 카페라떼 판매 갯수: 1
# 카푸치노 판매 갯수: 0
# 총 매출은  9000 원입니다.

# %%
print( '셀 병합 \n \t \'shift key\'를 누른후 \n \t \t병합을 원하는 셀들을 다중선택 후 shift+M')
# Out:
# 셀 병합
#  	 'shift key'를 누른후
#  	 	병합을 원하는 셀들을 다중선택 후 shift+M

# %%
a = 8 == 12
print(a, type(a))
# Out:
# False <class 'bool'>

# %%
b = 'apple' == 'APPLE'
print(b, type(b))
# Out:
# False <class 'bool'>

# %%
c = 8 != 12
print(c,type(c))
# Out:
# True <class 'bool'>
